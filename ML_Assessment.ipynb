# %% [markdown]
# # Wine Analysis
# In this assignment, you are given access to a set of training data related to wine quality. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.). Your goal is to perform two tasks on the data:
# ## Your tasks:
# ### 1: Predict quality -in  a range of 0 to 10
# ### 2: Predict color - red or white

# %% [markdown]
# ## Your data
#    1 - fixed acidity - Can be: low, below average, average, above average, high
#
# The rest of the columns are continuous data:
#
# 2 - volatile acidity
#
# 3 - citric acid
#
# 4 - residual sugar
#
# 5 - chlorides
#
# 6 - free sulfur dioxide
#
# 7 - total sulfur dioxide
#
# 8 - density
#
# 9 - pH
#
# 10 - sulphates
#
# 11 - alcohol

# %% [markdown]
# ## Expectations
# I will leave most of the decision-making up to you. You should:
# 1. Include text boxes explaining any important decisions you have made within your code. For example, changing a hyperparameter, dropping a column, one-hot encoding a column, etc. This is not an exhaustive list. This should be a trail of bread crumbs that someone else could follow.
# 2. You should include a RMSE with % of standard deviation and/or an accuracy % at the bottom of your analyses. Meaning when you finish any regression, you should include a RMSE with % of standard deviation. When you finish a classification, you should include an accuracy %.

# %%
import pandas as pd
wine_data = pd.read_csv("https://raw.githubusercontent.com/modengann/Data-sets/master/wine_data.csv")

y_color = wine_data["color"]
y_quality = wine_data["quality"]
X = wine_data.drop(labels = ["color", "quality"], axis =1 )
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0     below average              0.70         0.00             1.9      0.076
# 1     below average              0.88         0.00             2.6      0.098
# 2     below average              0.76         0.04             2.3      0.092
# 3           average              0.28         0.56             1.9      0.075
# 4     below average              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            low              0.21         0.29             1.6      0.039
# 6493            low              0.32         0.36             8.0      0.047
# 6494            low              0.24         0.19             1.2      0.041
# 6495            low              0.29         0.30             1.1      0.022
# 6496            low              0.21         0.38             0.8      0.020
#
# ...

# %%
X
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0     below average              0.70         0.00             1.9      0.076
# 1     below average              0.88         0.00             2.6      0.098
# 2     below average              0.76         0.04             2.3      0.092
# 3           average              0.28         0.56             1.9      0.075
# 4     below average              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            low              0.21         0.29             1.6      0.039
# 6493            low              0.32         0.36             8.0      0.047
# 6494            low              0.24         0.19             1.2      0.041
# 6495            low              0.29         0.30             1.1      0.022
# 6496            low              0.21         0.38             0.8      0.020
#
# ...

# %%
y_color
# Out:
# 0         red
# 1         red
# 2         red
# 3         red
# 4         red
#         ...
# 6492    white
# 6493    white
# 6494    white
# 6495    white
# 6496    white
# Name: color, Length: 6497, dtype: object

# %%
y_quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64
